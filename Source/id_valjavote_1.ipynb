# %%
# VAATA DOKUMENTATSIOONI KUI LISA INFOT VAJA
# PEALE SELLE KOODI KASUTAMIST TULEB KÄIVITADA TEINE KOOD(ID_scrape.py) ILMSELT KA TEISES PYTHONI ENVIROMENTIS, KUNA GEOPYTHON ENVIROMENTIS POLE playwright LIBRARIT. 
# SAMUTI EI SAA KAHJUKS KOODI JOOKSUTADA JUPYTER LABIS.

# %%
import json
import folium

# %%
# .json faili import 
# scrape_trt.json faili asemele peab panema json faili kuhu andmed salvestati.
with open('scrape_trt.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
# Asukoha punktide välja korjamine
locations = []
for marker in data.get('markers', []):
    try:
        lat = marker["0"]
        lon = marker["1"]
        locations.append((lat, lon))
    except KeyError:
        continue

print(f"välja korjati {len(locations)} punkti.")
# Out:
# välja korjati 48 punkti.

# %%
# Kaardi tegemine andmete kontrollimseks. pole otseselt vajalik.
# Näitab hästi aga kuidas andmeid klasterdati
map_center = [58.3776, 26.7290]
rental_map = folium.Map(location=map_center, zoom_start=13)

# %%
for lat, lon in locations:
    folium.Marker([lat, lon]).add_to(rental_map)

# %%
import folium

rental_map = folium.Map(location=[58.3776, 26.7290], zoom_start=13)

for marker in data["markers"]:
    lat = marker.get("0")
    lon = marker.get("1")
    count = marker.get("count", 1)
    object_ids = marker.get("object_ids", "")

    if lat is None or lon is None:
        continue

    ids = object_ids.split(",") if object_ids else []

    if count == 1 or not ids:
        # Single listing or unknown breakdown
        folium.Marker([lat, lon], popup="1 listing").add_to(rental_map)
    else:
        # Multiple listings at one location
        popup_text = f"{count} listings:\n" + "\n".join(ids)
        folium.Marker([lat, lon], popup=popup_text).add_to(rental_map)

rental_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2 = L.map(
#                 &quot;map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2&quot;,
#                 {
#                     center: [58.3776, 26.729],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfe0b2e66fbeb34fa532ddb930fffcc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cfe0b2e66fbeb34fa532ddb930fffcc7.addTo(map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2);
#
#
#             var marker_162ceab8faf9d96a2f9467cb08d6367e = L.marker(
#                 [58.37974104589984, 26.723511431468545],
#                 {
# }
#             ).addTo(map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2);
#
#
#         var popup_1b2ab3ed9d58e01abba930aeed43c05e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c8a1f10a88be9193f10f3d322bcdcdf = $(`&lt;div id=&quot;html_6c8a1f10a88be9193f10f3d322bcdcdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;13 listings: 3158572 2976214 3667513 3748576 3364248 3222224 3745452 3716817 3748653 3745559 3737020 3731628 3751139&lt;/div&gt;`)[0];
#                 popup_1b2ab3ed9d58e01abba930aeed43c05e.setContent(html_6c8a1f10a88be9193f10f3d322bcdcdf);
#
#
#
#         marker_162ceab8faf9d96a2f9467cb08d6367e.bindPopup(popup_1b2ab3ed9d58e01abba930aeed43c05e)
#         ;
#
#
#
#
#             var marker_8439bb7ea1d13b542e23f9335b1ceadc = L.marker(
#                 [58.382988, 26.718329799999996],
#                 {
# }
#             ).addTo(map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2);
#
#
#         var popup_b06de1fac9229f9b0db0f5532fd25ca2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10db3e8a405fe28326d3e0ee9fe63d76 = $(`&lt;div id=&quot;html_10db3e8a405fe28326d3e0ee9fe63d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;31 listings: 3750691 3740344 3274135 3198841 3463010 3718550 3235129 3485700 3734001 3678099 3730300 3460433 3733522 3318047 3746267 3740445 3750345 3460419 3484647 3733074 3736338 3748467 3442681 3749040 3751300 3042165 3746100 3706689 3719765 3421570 3617466&lt;/div&gt;`)[0];
#                 popup_b06de1fac9229f9b0db0f5532fd25ca2.setContent(html_10db3e8a405fe28326d3e0ee9fe63d76);
#
#
#
#         marker_8439bb7ea1d13b542e23f9335b1ceadc.bindPopup(popup_b06de1fac9229f9b0db0f5532fd25ca2)
#         ;
#
#
#
#
#             var marker_beca9063ab7ed950a64aa24d5cc6cebb = L.marker(
#                 [58.3504106943687, 26.683165088258235],
#                 {
# }
#             ).addTo(map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2);
#
#
#         var popup_4b5db69e3ccea739ed7e6d96be9828d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57d4ad7acf083eba9b86dcc545ecb640 = $(`&lt;div id=&quot;html_57d4ad7acf083eba9b86dcc545ecb640&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;13 listings: 3291511 3734970 3748094 3716787 3750774 3747738 3161319 3408651 3750449 3750209 3578646 3613219 3747063&lt;/div&gt;`)[0];
#                 popup_4b5db69e3ccea739ed7e6d96be9828d0.setContent(html_57d4ad7acf083eba9b86dcc545ecb640);
#
#
#
#         marker_beca9063ab7ed950a64aa24d5cc6cebb.bindPopup(popup_4b5db69e3ccea739ed7e6d96be9828d0)
#         ;
#
#
#
#
#             var marker_02052a423f7a5a8898ad8a76643d1875 = L.marker(
#                 [58.374575552544634, 26.722255966605708],
#                 {
# }
#             ).addTo(map_e5e4676b5bdcbc5ce2ab8dd0fa8c0db2);
#
#
#         var popup_d8c5a3c7b4bddb5830e09aa72bc376f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd443b60a4f77c3bb537e7d42f516cce = $(`&lt;div id=&quot;html_fd443b60a4f77c3bb537e7d42f516cce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;61 listings: 3252537 3460287 3750728 3565213 3618550 3435396 3724774 3651086 3729333 3558783 3736676 3300002 3333415 3256880 3737821 3749850 3745960 3661040 3534124 3486133 3745542 3679763 3710029 3744877 2944869 3418097 3556112 3748266 3723707 3636949 3604728 3750601 3748491 3723709 3260659 3737389 3710069 3196854 3718502 3702569 3651071 3745535 3610088 2666063 3749310 3379802 3675772 3744321 3653857 3380561 3743043 3198075 3178268 3734719 3748745 3192001 3744603 3647709 3749645 3751243 1888965&lt;/div&gt;`)[0];
#                 popup_d8c5a3c7b4bddb5830e09aa72bc376f5.setContent(html_fd443b60a4f77c3bb537e7d42f516cce);
#
#
#
#         marker_02052a423f7a5a8898ad8a76643d1875.bindPo

# %%
# Leian kõik object id-d klastritest

# %%
# json faili sisse laadimine
# with open("kv_response.json", "r", encoding="utf-8") as f:
    # data = json.load(f)

# %%
# ID-d välja korjamine klastritest
all_ids = set()

for marker in data.get("markers", []):
    object_ids = marker.get("object_ids", "")
    if object_ids:
        all_ids.update(object_ids.split(","))

object_id_list = sorted(all_ids)

print(f"Välja korjati {len(object_id_list)} unikaalset object ID-d.")
# Out:
# Välja korjati 331 unikaalset object ID-d.

# %%
# unikaalsete ID-d nimekiri. Seda on vaja!
object_id_list
# Out:
# ['1511073',
#  '1888965',
#  '2005285',
#  '2303976',
#  '2321504',
#  '2344155',
#  '2561825',
#  '2587858',
#  '2666063',
#  '2749072',
#  '2944869',
#  '2945377',
#  '2946160',
#  '2976214',
#  '3042165',
#  '3046003',
#  '3047651',
#  '3048974',
#  '3058386',
#  '3060907',
#  '3070373',
#  '3099062',
#  '3109898',
#  '3125725',
#  '3153451',
#  '3157199',
#  '3158572',
#  '3161319',
#  '3163262',
#  '3170315',
#  '3178268',
#  '3192001',
#  '3196854',
#  '3198075',
#  '3198841',
#  '3201110',
#  '3203352',
#  '3210527',
#  '3222224',
#  '3235129',
#  '3244505',
#  '3246179',
#  '3252537',
#  '3254500',
#  '3256880',
#  '3260659',
#  '3274135',
#  '3291511',
#  '3296651',
#  '3300002',
#  '3307919',
#  '3313995',
#  '3318047',
#  '3333415',
#  '3364248',
#  '3364613',
#  '3369935',
#  '3373227',
#  '3376480',
#  '3379802',
#  '3380561',
#  '3387644',
#  '3395635',
#  '3397809',
#  '3408651',
#  '3410255',
#  '3418097',
#  '3421570',
#  '3435396',
#  '3440727',
#  '3441272',
#  '3442681',
#  '3446800',
#  '3451649',
#  '3459603',
#  '3460287',
#  '3460419',
#  '3460433',
#  '3463010',
#  '3463733',
#  '3466825',
#  '3472280',
#  '3474819',
#  '3484647',
#  '3485700',
#  '3486133',
#  '3522174',
#  '3529644',
#  '3534124',
#  '3534156',
#  '3540521',
#  '3548746',
#  '3550447',
#  '3550464',
#  '3551200',
#  '3551284',
#  '3554083',
#  '3554437',
#  '3556112',
#  '3558783',
#  '3561158',
#  '3564733',
#  '3565213',
#  '3572275',
#  '3578646',
#  '3578854',
#  '3580565',
#  '3582759',
#  '3589232',
#  '3596143',
#  '3601381',
#  '3604728',
#  '3610088',
#  '3612371',
#  '3613219',
#  '3617466',
#  '3618550',
#  '3620939',
#  '3621757',
#  '3623360',
#  '3627264',
#  '3628632',
#  '3631530',
#  '3634671',
#  '3635652',
#  '3636949',
#  '3643442',
#  '3643701',
#  '3647709',
#  '3650385',
#  '3651071',
#  '3651086',
#  '3651886',
#  '3653857',
#  '3654070',
#  '3659946',
#  '3661040',
#  '3665509',
#  '3665747',
#  '3667513',
#  '3668230',
#  '3675772',
#  '3678099',
#  '3679763',
#  '3681459',
#  '3684738',
#  '3686237',
#  '3686979',
#  '3688082',
#  '3691843',
#  '3695684',
#  '3696698',
#  '3699032',
#  '3702438',
#  '3702569',
#  '3704446',
#  '3706106',
#  '3706579',
#  '3706586',
#  '3706689',
#  '3710029',
#  '3710069',
#  '3711690',
#  '3714989',
#  '3716787',
#  '3716817',
#  '3717734',
#  '3718502',
#  '3718550',
#  '3719083',
#  '3719755',
#  '3719765',
#  '3720506',
#  '3720736',
#  '3722437',
#  '3722641',
#  '3723707',
#  '3723709',
#  '3724025',
#  '3724774',
#  '3725033',
#  '3725076',
#  '3726515',
#  '3726527',
#  '3727451',
#  '3729333',
#  '3730300',
#  '3731560',
#  '3731628',
#  '3733074',
#  '3733522',
#  '3733707',
#  '3734001',
#  '3734390',
#  '3734719',
#  '3734970',
#  '3735937',
#  '3735973',
#  '3736251',
#  '3736338',
#  '3736361',
#  '3736676',
#  '3737020',
#  '3737389',
#  '3737814',
#  '3737821',
#  '3737840',
#  '3737949',
#  '3738738',
#  '3739021',
#  '3739437',
#  '3739810',
#  '3739813',
#  '3739838',
#  '3739888',
#  '3739932',
#  '3739997',
#  '3740344',
#  '3740425',
#  '3740445',
#  '3740461',
#  '3740478',
#  '3740971',
#  '3741054',
#  '3741332',
#  '3741517',
#  '3741822',
#  '3741848',
#  '3741986',
#  '3742353',
#  '3742514',
#  '3742563',
#  '3743043',
#  '3743738',
#  '3744321',
#  '3744395',
#  '3744603',
#  '3744735',
#  '3744781',
#  '3744877',
#  '3744900',
#  '3744976',
#  '3745341',
#  '3745410',
#  '3745452',
#  '3745494',
#  '3745498',
#  '3745535',
#  '3745542',
#  '3745546',
#  '3745559',
#  '3745642',
#  '3745827',
#  '3745936',
#  '3745960',
#  '3746100',
#  '3746144',
#  '3746149',
#  '3746267',
#  '3746537',
#  '3746544',
#  '3746690',
#  '3746734',
#  '3747063',
#  '3747067',
#  '3747145',
#  '3747247',
#  '3747379',
#  '3747725',
#  '3747738',
#  '3747859',
#  '3748094',
#  '3748266',
#  '3748393',
#  '3748467',
#  '3748489',
#  '3748491',
#  '3748495',
#  '3748576',
#  '3748614',
#  '3748630',
#  '3748653',
#  '3748745',
#  '3748767',
#  '3748777',
#  '3748923',
#  '3749040',
#  '3749302',
#  '3749310',
#  '3749492',
#  '3749591',
#  '3749645',
#  '3749818',
#  '3749850',
#  '3750120',
#  '3750190',
#  '3750209',
#  '3750256',
#  '3750345',
#  '3750380',
#  '3750397',
#  '3750402',
#  '3750449',
#  '3750523',
#  '3750540',
#  '3750541',
#  '3750601',
#  '3750613',
#  '3750647',
#  '3750691',
#  '3750728',
#  '3750774',
#  '3750931',
#  '3751031',
#  '3751139',
#  '3751164',
#  '3751171',
#  '3751183',
#  '3751198',
#  '3751243',
#  '3751248',
#  '3751250',
#  '3751251',
#  '3751300',
#  '3751314',
#  '3751377',
#  '3751410',
#  '3751426',
#  '3751432',
#  '3751504',
#  '3751508']

# %%
# PEALE SELLE KOODI KASUTAMIST TULEB KÄIVITADA TEINE KOOD(ID_scrape.py) ILMSELT KA TEISES PYTHONI ENVIROMENTIS, KUNA GEOPYTHON ENVIROMENTIS POLE playwright LIBRARIT. 
# SAMUTI EI SAA KAHJUKS KOODI JOOKSUTADA JUPYTER LABIS.

# %%
# MILLISED LIBRARID LISASIN UUTE ENVIROMENTI:
# playwright
# ipykernel
# folium

# %%
# object_id_list ID-d kopeerida ID_scrape.py skripti. Väärtused tuleb kopeerida “object-ids = []” kantsulgude vahele.

# %%
# kui andmed on kooritud tuleb andmed korrastada
# Selleks tuleks liikuda skripti Andmete_korrastus.ipynb
